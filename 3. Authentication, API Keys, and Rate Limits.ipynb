# %% [markdown]
# <h1> Introduction to API Authentication

# %%
import requests
import json

url = 'https://api-server.dataquest.io/private/economic_data'
response = requests.get(url)
print(response.status_code)
print(response.text)
# Out:
# 401
# {"error":"Unauthorized"}

# %% [markdown]
# <h1> Navigating API Documentation

# %% [markdown]
# <h1> Basic Authentication

# %%
import base64

username = "dq"
password = "test"
encoded_credentials = base64.b64encode(f"{username}:{password}".encode()).decode()

# %%
headers = {
    'Authorization': f'Basic {encoded_credentials}'
}

url = "https://api-server.dataquest.io/private/economic_data/FootNotes"
response = requests.get(url, headers=headers)

data = json.loads(response.json())

data
# Out:
# [{'countrycode': 'ABW',
#   'seriescode': 'IT.NET.SECR',
#   'year': 'YR2012',
#   'description': 'December, 2012',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'PA.NUS.PRVT.PP',
#   'year': 'YR2012',
#   'description': 'ICP annual PPP estimate',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'PA.NUS.PRVT.PP',
#   'year': 'YR2016',
#   'description': 'ICP annual PPP estimate',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'PA.NUS.PRVT.PP',
#   'year': 'YR2015',
#   'description': 'ICP annual PPP estimate',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'PA.NUS.PRVT.PP',
#   'year': 'YR2014',
#   'description': 'ICP annual PPP estimate',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'PA.NUS.PRVT.PP',
#   'year': 'YR2013',
#   'description': 'ICP annual PPP estimate',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'PA.NUS.PPP',
#   'year': 'YR2014',
#   'description': 'ICP annual PPP estimate',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'PA.NUS.PPP',
#   'year': 'YR2013',
#   'description': 'ICP annual PPP estimate',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'PA.NUS.PPP',
#   'year': 'YR2012',
#   'description': 'ICP annual PPP estimate',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'PA.NUS.PPP',
#   'year': 'YR2016',
#   'description': 'ICP annual PPP estimate',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'PA.NUS.PPP',
#   'year': 'YR2015',
#   'description': 'ICP annual PPP estimate',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'PA.NUS.PPP',
#   'year': 'YR2017',
#   'description': 'ICP benchmark PPP',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'PA.NUS.PPP',
#   'year': 'YR2011',
#   'description': 'ICP benchmark PPP',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'PA.NUS.PRVT.PP',
#   'year': 'YR2017',
#   'description': 'ICP benchmark PPP',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'PA.NUS.PRVT.PP',
#   'year': 'YR2011',
#   'description': 'ICP benchmark PPP',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.UEM.TOTL.NE.ZS',
#   'year': 'YR2001',
#   'description': 'LFS - Labour Force Survey.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.UEM.TOTL.NE.ZS',
#   'year': 'YR2011',
#   'description': 'LFS - Labour Force Survey.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.UEM.TOTL.MA.NE.ZS',
#   'year': 'YR2001',
#   'description': 'LFS - Labour Force Survey.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.UEM.TOTL.MA.NE.ZS',
#   'year': 'YR2011',
#   'description': 'LFS - Labour Force Survey.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.UEM.TOTL.FE.NE.ZS',
#   'year': 'YR2001',
#   'description': 'LFS - Labour Force Survey.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.UEM.TOTL.FE.NE.ZS',
#   'year': 'YR2011',
#   'description': 'LFS - Labour Force Survey.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.TLF.CACT.NE.ZS',
#   'year': 'YR2011',
#   'description': 'LFS - Labour Force Survey.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.TLF.CACT.MA.NE.ZS',
#   'year': 'YR2011',
#   'description': 'LFS - Labour Force Survey.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.TLF.CACT.FE.NE.ZS',
#   'year': 'YR2011',
#   'description': 'LFS - Labour Force Survey.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.EMP.TOTL.SP.NE.ZS',
#   'year': 'YR2011',
#   'description': 'LFS - Labour Force Survey.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.EMP.TOTL.SP.MA.NE.ZS',
#   'year': 'YR2011',
#   'description': 'LFS - Labour Force Survey.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.EMP.TOTL.SP.FE.NE.ZS',
#   'year': 'YR2011',
#   'description': 'LFS - Labour Force Survey.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.UEM.TOTL.NE.ZS',
#   'year': 'YR2007',
#   'description': 'LFS - Labour Force Survey. Data reference period: October.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.UEM.TOTL.NE.ZS',
#   'year': 'YR1997',
#   'description': 'LFS - Labour Force Survey. Data reference period: October.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.UEM.TOTL.NE.ZS',
#   'year': 'YR1994',
#   'description': 'LFS - Labour Force Survey. Data reference period: October.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.UEM.TOTL.FE.NE.ZS',
#   'year': 'YR2007',
#   'description': 'LFS - Labour Force Survey. Data reference period: October.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.UEM.TOTL.FE.NE.ZS',
#   'year': 'YR1997',
#   'description': 'LFS - Labour Force Survey. Data reference period: October.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.UEM.TOTL.FE.NE.ZS',
#   'year': 'YR1994',
#   'description': 'LFS - Labour Force Survey. Data reference period: October.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.UEM.TOTL.MA.NE.ZS',
#   'year': 'YR2007',
#   'description': 'LFS - Labour Force Survey. Data reference period: October.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.UEM.TOTL.MA.NE.ZS',
#   'year': 'YR1997',
#   'description': 'LFS - Labour Force Survey. Data reference period: October.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.UEM.TOTL.MA.NE.ZS',
#   'year': 'YR1994',
#   'description': 'LFS - Labour Force Survey. Data reference period: October.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.EMP.TOTL.SP.NE.ZS',
#   'year': 'YR2007',
#   'description': 'LFS - Labour Force Survey. Data reference period: October.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.EMP.TOTL.SP.MA.NE.ZS',
#   'year': 'YR2007',
#   'description': 'LFS - Labour Force Survey. Data reference period: October.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.EMP.TOTL.SP.FE.NE.ZS',
#   'year': 'YR2007',
#   'description': 'LFS - Labour Force Survey. Data reference period: October.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.UEM.TOTL.NE.ZS',
#   'year': 'YR2000',
#   'description': 'PC - Population and Housing Census. Data reference period: October.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.UEM.TOTL.MA.NE.ZS',
#   'year': 'YR2000',
#   'description': 'PC - Population and Housing Census. Data reference period: October.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.UEM.TOTL.FE.NE.ZS',
#   'year': 'YR2000',
#   'description': 'PC - Population and Housing Census. Data reference period: October.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.EMP.TOTL.SP.NE.ZS',
#   'year': 'YR2000',
#   'description': 'PC - Population and Housing Census. Data reference period: October.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.TLF.CACT.FE.NE.ZS',
#   'year': 'YR2000',
#   'description': 'PC - Population and Housing Census. Data reference period: October.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.TLF.CACT.MA.NE.ZS',
#   'year': 'YR2000',
#   'description': 'PC - Population and Housing Census. Data reference period: October.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.TLF.CACT.NE.ZS',
#   'year': 'YR2000',
#   'description': 'PC - Population and Housing Census. Data reference period: October.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.EMP.TOTL.SP.FE.NE.ZS',
#   'year': 'YR2000',
#   'description': 'PC - Population and Housing Census. Data reference period: October.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.EMP.TOTL.SP.MA.NE.ZS',
#   'year': 'YR2000',
#   'description': 'PC - Population and Housing Census. Data reference period: October.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.UEM.NEET.ZS',
#   'year': 'YR2010',
#   'description': 'PC - Population and Housing Census. Data reference period: September.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.UEM.NEET.MA.ZS',
#   'year': 'YR2010',
#   'description': 'PC - Population and Housing Census. Data reference period: September.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.UEM.NEET.FE.ZS',
#   'year': 'YR2010',
#   'description': 'PC - Population and Housing Census. Data reference period: September.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.UEM.TOTL.NE.ZS',
#   'year': 'YR2010',
#   'description': 'PC - Population and Housing Census. Data reference period: September. Age coverage - minimum age: 14 years old. Nonstandard age group: Including age 14.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.UEM.TOTL.MA.NE.ZS',
#   'year': 'YR2010',
#   'description': 'PC - Population and Housing Census. Data reference period: September. Age coverage - minimum age: 14 years old. Nonstandard age group: Including age 14.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.UEM.1524.MA.NE.ZS',
#   'year': 'YR2010',
#   'description': 'PC - Population and Housing Census. Data reference period: September. Age coverage - minimum age: 14 years old. Nonstandard age group: Including age 14.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.UEM.1524.NE.ZS',
#   'year': 'YR2010',
#   'description': 'PC - Population and Housing Census. Data reference period: September. Age coverage - minimum age: 14 years old. Nonstandard age group: Including age 14.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.UEM.TOTL.FE.NE.ZS',
#   'year': 'YR2010',
#   'description': 'PC - Population and Housing Census. Data reference period: September. Age coverage - minimum age: 14 years old. Nonstandard age group: Including age 14.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.UEM.1524.FE.NE.ZS',
#   'year': 'YR2010',
#   'description': 'PC - Population and Housing Census. Data reference period: September. Age coverage - minimum age: 14 years old. Nonstandard age group: Including age 14.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.UEM.TOTL.NE.ZS',
#   'year': 'YR1991',
#   'description': 'PC - Population and Housing Census. Data reference period: October. Age coverage - minimum age: 14 years old.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.UEM.1524.NE.ZS',
#   'year': 'YR1991',
#   'description': 'PC - Population and Housing Census. Data reference period: October. Age coverage - minimum age: 14 years old.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.UEM.TOTL.FE.NE.ZS',
#   'year': 'YR1991',
#   'description': 'PC - Population and Housing Census. Data reference period: October. Age coverage - minimum age: 14 years old.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.UEM.TOTL.MA.NE.ZS',
#   'year': 'YR1991',
#   'description': 'PC - Population and Housing Census. Data reference period: October. Age coverage - minimum age: 14 years old.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.UEM.1524.FE.NE.ZS',
#   'year': 'YR1991',
#   'description': 'PC - Population and Housing Census. Data reference period: October. Age coverage - minimum age: 14 years old.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.UEM.1524.MA.NE.ZS',
#   'year': 'YR1991',
#   'description': 'PC - Population and Housing Census. Data reference period: October. Age coverage - minimum age: 14 years old.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.EMP.TOTL.SP.NE.ZS',
#   'year': 'YR1991',
#   'description': 'PC - Population and Housing Census. Data reference period: October. Age coverage - minimum age: 14 years old.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.EMP.TOTL.SP.MA.NE.ZS',
#   'year': 'YR1991',
#   'description': 'PC - Population and Housing Census. Data reference period: October. Age coverage - minimum age: 14 years old.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.EMP.TOTL.SP.FE.NE.ZS',
#   'year': 'YR1991',
#   'description': 'PC - Population and Housing Census. Data reference period: October. Age coverage - minimum age: 14 years old.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.TLF.CACT.NE.ZS',
#   'year': 'YR1991',
#   'description': 'PC - Population and Housing Census. Age coverage - minimum age: 14 years old.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.TLF.CACT.NE.ZS',
#   'year': 'YR1981',
#   'description': 'PC - Population and Housing Census. Age coverage - minimum age: 14 years old.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.TLF.CACT.NE.ZS',
#   'year': 'YR1972',
#   'description': 'PC - Population and Housing Census. Age coverage - minimum age: 14 years old.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.TLF.CACT.NE.ZS',
#   'year': 'YR1960',
#   'description': 'PC - Population and Housing Census. Age coverage - minimum age: 14 years old.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.TLF.CACT.MA.NE.ZS',
#   'year': 'YR1991',
#   'description': 'PC - Population and Housing Census. Age coverage - minimum age: 14 years old.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.TLF.CACT.MA.NE.ZS',
#   'year': 'YR1981',
#   'description': 'PC - Population and Housing Census. Age coverage - minimum age: 14 years old.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.TLF.CACT.MA.NE.ZS',
#   'year': 'YR1972',
#   'description': 'PC - Population and Housing Census. Age coverage - minimum age: 14 years old.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.TLF.CACT.MA.NE.ZS',
#   'year': 'YR1960',
#   'description': 'PC - Population and Housing Census. Age coverage - minimum age: 14 years old.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.TLF.CACT.FE.NE.ZS',
#   'year': 'YR1981',
#   'description': 'PC - Population and Housing Census. Age coverage - minimum age: 14 years old.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.TLF.CACT.FE.NE.ZS',
#   'year': 'YR1972',
#   'description': 'PC - Population and Housing Census. Age coverage - minimum age: 14 years old.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.TLF.CACT.FE.NE.ZS',
#   'year': 'YR1960',
#   'description': 'PC - Population and Housing Census. Age coverage - minimum age: 14 years old.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.TLF.ACTI.1524.NE.ZS',
#   'year': 'YR1991',
#   'description': 'PC - Population and Housing Census. Age coverage - minimum age: 14 years old.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.TLF.CACT.FE.NE.ZS',
#   'year': 'YR1991',
#   'description': 'PC - Population and Housing Census. Age coverage - minimum age: 14 years old.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.TLF.ACTI.1524.MA.NE.ZS',
#   'year': 'YR1991',
#   'description': 'PC - Population and Housing Census. Age coverage - minimum age: 14 years old.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.TLF.ACTI.1524.FE.NE.ZS',
#   'year': 'YR1991',
#   'description': 'PC - Population and Housing Census. Age coverage - minimum age: 14 years old.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.TLF.CACT.NE.ZS',
#   'year': 'YR2010',
#   'description': 'PC - Population and Housing Census. Data reference period: September. Nonstandard age group: Including age 14.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.TLF.CACT.MA.NE.ZS',
#   'year': 'YR2010',
#   'description': 'PC - Population and Housing Census. Data reference period: September. Nonstandard age group: Including age 14.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.TLF.CACT.FE.NE.ZS',
#   'year': 'YR2010',
#   'description': 'PC - Population and Housing Census. Data reference period: September. Nonstandard age group: Including age 14.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.EMP.TOTL.SP.NE.ZS',
#   'year': 'YR2010',
#   'description': 'PC - Population and Housing Census. Data reference period: September. Nonstandard age group: Including age 14.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.EMP.TOTL.SP.MA.NE.ZS',
#   'year': 'YR2010',
#   'description': 'PC - Population and Housing Census. Data reference period: September. Nonstandard age group: Including age 14.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.EMP.TOTL.SP.FE.NE.ZS',
#   'year': 'YR2010',
#   'description': 'PC - Population and Housing Census. Data reference period: September. Nonstandard age group: Including age 14.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.TLF.CACT.MA.NE.ZS',
#   'year': 'YR2007',
#   'description': 'LFS - Labour Force Survey. Data reference period: October. Population coverage: Including armed forces and/or conscripts.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.TLF.CACT.NE.ZS',
#   'year': 'YR2007',
#   'description': 'LFS - Labour Force Survey. Data reference period: October. Population coverage: Including armed forces and/or conscripts.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.TLF.ACTI.1524.MA.NE.ZS',
#   'year': 'YR2007',
#   'description': 'LFS - Labour Force Survey. Data reference period: October. Population coverage: Including armed forces and/or conscripts.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.TLF.ACTI.1524.NE.ZS',
#   'year': 'YR2007',
#   'description': 'LFS - Labour Force Survey. Data reference period: October. Population coverage: Including armed forces and/or conscripts.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.TLF.CACT.FE.NE.ZS',
#   'year': 'YR2007',
#   'description': 'LFS - Labour Force Survey. Data reference period: October. Population coverage: Including armed forces and/or conscripts.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'SL.TLF.ACTI.1524.FE.NE.ZS',
#   'year': 'YR2007',
#   'description': 'LFS - Labour Force Survey. Data reference period: October. Population coverage: Including armed forces and/or conscripts.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'IT.MLT.MAIN',
#   'year': 'YR2010',
#   'description': 'Source: Directorate of Telecommunication Affairs Aruba.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'IT.NET.BBND',
#   'year': 'YR2010',
#   'description': 'Source: Directorate of Telecommunication Affairs Aruba.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'IT.NET.BBND',
#   'year': 'YR2008',
#   'description': 'Source: Directorate of Telecommunication Affairs Aruba.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'IT.NET.BBND',
#   'year': 'YR2007',
#   'description': 'Source: Directorate of Telecommunication Affairs Aruba.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'IT.CEL.SETS',
#   'year': 'YR2014',
#   'description': 'Source: ITU estimate.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'IT.CEL.SETS',
#   'year': 'YR2013',
#   'description': 'Source: ITU estimate.',
#   'unnamed:_4': None},
#  {'countrycode': 'ABW',
#   'seriescode': 'IT.CEL.SETS',
#   'year': 'YR2012',
#   'description': 'Source: ITU estimate.',
#   'unnamed:_4': None}]

# %%
username = "dq"
password = "test"

encoded_credentials = base64.b64encode(f"{username}:{password}".encode()).decode()

base_url = "https://api-server.dataquest.io/private/economic_data"
url_historical_data = base_url + "/historical_data"
headers = {
    'Authorization': f'Basic {encoded_credentials}'
}

response = requests.get(url_historical_data, headers= headers)

print(response.status_code)
if response.status_code == 200:
    response_preview = response.text[:500]
    print("Response Preview:", response_preview)
# Out:
# 200
# Response Preview: "[{\"country_name\": \"Africa Eastern and Southern\", \"country_code\": \"AFE\", \"indicator_name\": \"Access to clean fuels and technologies for cooking (% of population)\", \"indicator_code\": \"EG.CFT.ACCS.ZS\", \"1960\": null, \"1961\": null, \"1962\": null, \"1963\": null, \"1964\": null, \"1965\": null, \"1966\": null, \"1967\": null, \"1968\": null, \"1969\": null, \"1970\": null, \"1971\": null, \"1972\": null, \"1973\": null, \"1974\": null, \"1975\": null, \"1976\": null, \"1977\": nul

# %% [markdown]
# <h1>Environment Variable

# %%
import os

os.environ["USERNAME"] = 'your-username'
os.environ["PASSWORD"] = 'your-password'

# %%
# And to retrieve these credentials in your script:

username = os.environ.get('USERNAME')
password = os.environ.get('PASSWORD')

print(username, password)
# Out:
# your-username your-password

# %%
credentials.json = 
{
    "username": "your-username",
    "password": "your-password"
}

# Reading credentials from a file
with open('credentials.json', 'r') as file:
    credentials = json.load(file)
    username = credentials['username']
    password = credentials['password']
# Out:
#   Cell In[8], line 1
#     credentials.json =
#                        ^
# SyntaxError: invalid syntax

# %% [markdown]
# <h1>  Troubleshooting: Handling Authentication Errors

# %%
username = 'dq'
password = 'tests'

# Encode credentials using base64
encoded_credentials = base64.b64encode(f"{username}:{password}".encode()).decode()

# Set up headers for Basic Authentication
headers = {
    'Authorization': f'Basic {encoded_credentials}'
}

url = 'https://api-server.dataquest.io/private/economic_data/footnotes'

try:
    response = requests.get(url, headers=headers)
    response.raise_for_status()
except requests.exceptions.HTTPError as err:
    print(f"HTTP error occurred: {err}")  # Handling specific HTTP error
# Out:
# HTTP error occurred: 401 Client Error: Unauthorized for url: https://api-server.dataquest.io/private/economic_data/footnotes

# %%
username = 'eric'
password = '1708'

# Encode credentials using base64
encoded_credentials = base64.b64encode(f"{username}:{password}".encode()).decode()

# Set up headers 

headers = {
    'Authorization': f'Basic {encoded_credentials}' 
}

try:
    response = requests.get(url_historical_data, headers = headers)
    response.raise_for_status()
except requests.exceptions.HTTPError as err:
    print(f"HTTP error occured: {err}")
# Out:
# HTTP error occured: 401 Client Error: Unauthorized for url: https://api-server.dataquest.io/private/economic_data/historical_data

# %% [markdown]
# <h1> Understanding API Rate Limits and Quotas

# %%
import requests
import time
import base64

# Setting up Basic Authentication
username = 'dq'
password = 'test'
encoded_credentials = base64.b64encode(f"{username}:{password}".encode()).decode()
headers = {'Authorization': f'Basic {encoded_credentials}'}

url = 'https://api-server.dataquest.io/private/economic_data/historical_data'

# Attempting to send multiple requests to demonstrate exceeding the quota or rate limit
for i in range(1001):
    response = requests.get(url, headers=headers)
    print(response.status_code)
    if response.status_code == 429:
        print("Rate limit exceeded. Waiting for 60 seconds before next request.")
        time.sleep(60)  # Waiting for 1 minute before making the next
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# Rate limit exceeded. Waiting for 60 seconds before next request.
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# Rate limit exceeded. Waiting for 60 seconds before next request.
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 429
# Rate limit exceeded. Waiting for 60 seconds before next request.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 19
#      17 if response.status_code == 429:
#      18     print("Rate limit exceeded. Waiting for 60 seconds before next request.")
# ---> 19     time.sleep(60)  # Waiting for 1 minute before making the next
#
# KeyboardInterrupt:

# %% [markdown]
# <h1> Timing API Requests

# %%
url = 'https://api-server.dataquest.io/private/economic_data/footnotes'
username = 'dq'
password = 'test'
encoded_credentials = base64.b64encode(f"{username}:{password}".encode()).decode()
headers = {'Authorization': f'Basic {encoded_credentials}'}

for i in range(100):
    response = requests.get(url, headers=headers)
    print(response.status_code)
    time.sleep(0.6)
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %% [markdown]
# <h1> Dealing with Rate Limit

# %%
import requests
import time

url = 'https://api-server.dataquest.io/private/economic_data/footness'

username = 'dq'
password = 'test'
encoded_credentials = base64.b64encode(f"{username}:{password}".encode()).decode()
headers = {'Authorization': f'Basic {encoded_credentials}'}

for i in range(101): # Sending 101 requests to demonstrate the rate limit error
    response = requests.get(url, headers=headers)
    if response.status_code == 429:  # If we hit the rate limit
        print("Rate limit exceeded. Waiting for 60 seconds before next request.")
        time.sleep(60)  # Pause the script for 60 seconds
    else:
        print(response.status_code)
    time.sleep(0.6)  # Pause for 0.6 seconds between requests to respect the rate limit
# Out:
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# Rate limit exceeded. Waiting for 60 seconds before next request.
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400

# %% [markdown]
# <h1> Understanding API Key Authentication

# %%
import requests

# Hypothetical URL for an API that supports API key authentication
url = 'https://api.example.com/data'
headers = {'Authorization': 'Bearer YOUR_API_KEY'}

# Making a request with the API key
response = requests.get(url, headers=headers)
print(response.json())
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File c:\Python\Python310\lib\site-packages\urllib3\connection.py:198, in HTTPConnection._new_conn(self)
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#
# File c:\Python\Python310\lib\site-packages\urllib3\util\connection.py:60, in create_connection(address, timeout, source_address, socket_options)
#      58     raise LocationParseError(f"'{host}', label empty or too long") from None
# ---> 60 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      61     af, socktype, proto, canonname, sa = res
#
# File c:\Python\Python310\lib\socket.py:955, in getaddrinfo(host, port, family, type, proto, flags)
#     954 addrlist = []
# --> 955 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     956     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# The above exception was the direct cause of the following exception:
#
# NameResolutionError                       Traceback (most recent call last)
# File c:\Python\Python310\lib\site-packages\urllib3\connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#
# File c:\Python\Python310\lib\site-packages\urllib3\connectionpool.py:491, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     490         new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)
# --> 491     raise new_e
#     493 # conn.request() calls http.client.*.request, not the method in
#     494 # urllib3.request. It also calls makefile (recv) on the socket.
#
# File c:\Python\Python310\lib\site-packages\urllib3\connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     466 try:
# --> 467     self._validate_conn(conn)
#     468 except (SocketTimeout, BaseSSLError) as e:
#
# File c:\Python\Python310\lib\site-packages\urllib3\connectionpool.py:1099, in HTTPSConnectionPool._validate_conn(self, conn)
#    1098 if conn.is_closed:
# -> 1099     conn.connect()
#    1101 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File c:\Python\Python310\lib\site-packages\urllib3\connection.py:616, in HTTPSConnection.connect(self)
#     615 sock: socket.socket | ssl.SSLSocket
# --> 616 self.sock = sock = self._new_conn()
#     617 server_hostname: str = self.host
#
# File c:\Python\Python310\lib\site-packages\urllib3\connection.py:205, in HTTPConnection._new_conn(self)
#     204 except socket.gaierror as e:
# --> 205     raise NameResolutionError(self.host, self, e) from e
#     206 except SocketTimeout as e:
#
# NameResolutionError: <urllib3.connection.HTTPSConnection object at 0x000002909FB4F760>: Failed to resolve 'api.example.com' ([Errno 11001] getaddrinfo failed)
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File c:\Python\Python310\lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File c:\Python\Python310\lib\site-packages\urllib3\connectionpool.py:847, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     845     new_e = ProtocolError("Connection aborted.", new_e)
# --> 847 retries = retries.increment(
#     848     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     849 )
#     850 retries.sleep()
#
# File c:\Python\Python310\lib\site-packages\urllib3\util\retry.py:515, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     514     reason = error or ResponseError(cause)
# --> 515     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     517 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='api.example.com', port=443): Max retries exceeded with url: /data (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002909FB4F760>: Failed to resolve 'api.example.com' ([Errno 11001] getaddrinfo failed)"))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[16], line 8
#       5 headers = {'Authorization': 'Bearer YOUR_API_KEY'}
#       7 # Making a request with the API key
# ----> 8 response = requests.get(url, headers=headers)
#       9 print(response.json())
#
# File c:\Python\Python310\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Python\Python310\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Python\Python310\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Python\Python310\lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Python\Python310\lib\site-packages\requests\adapters.py:519, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     515     if isinstance(e.reason, _SSLError):
#     516         # This branch is for urllib3 v1.22 and later.
#     517         raise SSLError(e, request=request)
# --> 519     raise ConnectionError(e, request=request)
#     521 except ClosedPoolError as e:
#     522     raise ConnectionError(e, request=request)
#
# ConnectionError: HTTPSConnectionPool(host='api.example.com', port=443): Max retries exceeded with url: /data (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002909FB4F760>: Failed to resolve 'api.example.com' ([Errno 11001] getaddrinfo failed)"))
